# %%
import matplotlib.pyplot as plt

# %%
x_list = [i for i in range(1, 9)]

# %%
mps1_list = [
    0.0416056,
0.0288851,
0.0176048,
0.0315102,
0.0174371,
0.0441999,
0.0311031,
0.0373772
]
mps2_list = [0.0162413,
0.0165234,
0.0139028,
0.0173473,
0.0136257,
0.0345497,
0.0200509,
0.0193801]

# %%
plt.plot(x_list, mps1_list, label='MPS1')
plt.plot(x_list, mps2_list, label='MPS2')
plt.xlabel(r'$\lambda$')
plt.ylabel('Error')
plt.legend()
